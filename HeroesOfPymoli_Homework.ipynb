# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
heroes_data = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(heroes_data)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# ...

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
total_players = len(purchase_data['SN'].unique().tolist())
total_players
# Out:
# 576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
number_of_items = len(purchase_data['Item ID'].unique().tolist())
number_of_items
# Out:
# 183

# %%
average_purchase = purchase_data['Price'].mean()
average_purchase
# Out:
# 3.050987179487176

# %%
number_of_purchases = purchase_data['Purchase ID'].count()
number_of_purchases
# Out:
# 780

# %%
revenue = purchase_data['Price'].sum()
revenue
# Out:
# 2379.77

# %%
summary_data_1 = {'number_of_items': [183],
                  'average_purchase': [3.05],
                  'number_of_purchases': [780],
                  'revenue': [2379.77]}

df_1 = pd.DataFrame(summary_data_1)
df_1.head()
# Out:
#    number_of_items  average_purchase  number_of_purchases  revenue
# 0              183              3.05                  780  2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_groups = purchase_data.groupby('Gender')
users = gender_groups['SN'].nunique()
users.head()
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
percent_of_users = (users/total_players)*100
percent_of_users.head()

summary_data_2 = {'Female':[.1406],
                'Male':  [.8403],
                'Other/Non-Disclosed':  [.0191]}

df_2 = pd.DataFrame(summary_data_2)

df_2["Female"] = df_2["Female"].map("{0:.2f}%".format)
df_2["Male"] = df_2["Male"].map("{0:.2f}%".format)
df_2["Other/Non-Disclosed"] = df_2["Other/Non-Disclosed"].map("{0:.2f}%".format)
df_2.head()
# Out:
#   Female   Male Other/Non-Disclosed
# 0  0.14%  0.84%               0.02%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_by_gender = gender_groups['Purchase ID'].count()


print(purchase_by_gender)
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Purchase ID, dtype: int64

# %%
average_price_gender = gender_groups['Price'].mean()

print(average_price_gender)
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# Name: Price, dtype: float64

# %%
gender_revenue = gender_groups['Price'].sum()
print(gender_revenue)
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
avg_gender = gender_revenue / purchase_by_gender
print(avg_gender)
# Out:
# Gender
# Female                   3.203009
# Male                     3.017853
# Other / Non-Disclosed    3.346000
# dtype: float64

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
bins = [6, 10, 14, 18, 22, 26, 30, 34, 38, 42, 46, 50]

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
group_sn = purchase_data.groupby(['SN'])
group_sn.sum().head(10)

# top_spender = group_sn.sort_values("Price", ascending=False) - doesnt work?
# Out:
#               Purchase ID  Age  Item ID  Price
# SN
# Adairialis76          467   16      123   2.28
# Adastirin33           142   35      175   4.48
# Aeda94                388   17      128   4.91
# Aela59                 28   21      119   4.32
# Aelaria33             630   23      171   1.79
# Aelastirin39          984   46      134   7.29
# Aelidru27             705   22      183   1.09
# Aelin32               723   60      326   8.98
# Aelly27               471   48      130   6.79
# Aellynun67            286   25      153   3.74

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
profitable = purchase_data.groupby(['Item Name'])
profitable.count().head(20)
# Out:
#                                       Purchase ID  SN  Age  Gender  Item ID  \
# Item Name
# Abyssal Shard                                   5   5    5       5        5
# Aetherius, Boon of the Blessed                  5   5    5       5        5
# Agatha                                          6   6    6       6        6
# Alpha                                           3   3    3       3        3
# Alpha, Oath of Zeal                             3   3    3       3        3
# Alpha, Reach of Ending Hope                     1   1    1       1        1
# Amnesia                                         6   6    6       6        6
# Apocalyptic Battlescythe                        6   6    6       6        6
# Arcane Gem                                      3   3    3       3        3
# Avenger                                         6   6    6       6        6
# Azurewrath                                      6   6    6       6        6
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
profitable.sum().head(50)

# profitable_items = sum_item_profit.sort_values(["Price"], ascending=False)    --this doesnt work?
# Out:
#                                        Purchase ID  Age  Item ID  Price
# Item Name
# Abyssal Shard                                 1140  111      810  13.35
# Aetherius, Boon of the Blessed                2037  126      685  16.95
# Agatha                                        2305  124      720  18.48
# Alpha                                         2137   65      390   6.21
# Alpha, Oath of Zeal                           1602   68      237  12.15
# Alpha, Reach of Ending Hope                    664   31       47   3.58
# Amnesia                                       2509  128      132  13.08
# Apocalyptic Battlescythe                      3307  123      558  11.82
# Arcane Gem                                     931   66      252  11.37
# Avenger                                       1668  162      612  20.64
# Azurewrath                                    2520  122      960  26.40
# Betrayal, Whisper of Grieving Widows          1364  123      195  19.70
# ...

# %% [markdown]
# # Written Report
#
#     From this data you can learn many things. From the gender specific data, you can learn who you should target your advertising towards, males or females. This is important because it allows for the most efficient use of the companies money. Another observable trend within this data was males spending the highest amount of money overall on the game. This relates to the first point, in that it is helpful to know this, in order to come up with a plan for advertising. The final observation that I made while analysizing this data is that despite having less total users, females average to spend 20 cents more on the game, than males. I thought this was interesting, due to the fact even though their total number of users is lower, they seem to be more financially invested in the game, when playing.
